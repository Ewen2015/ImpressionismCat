# %%
import style2
# Out:
# 2022-06-02 13:53:59.265428: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-02 13:53:59.265462: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
path_content = 'scenery/s_verticle.jpg'
path_style = 'scenery/style_flower.jpg'

# %%
style = style2.StyleTransfer(path_content, path_style)

# %%
style.show_inputs()

# %%
style.optimize(iterations=5000, learning_rate=1)
# Out:
# Iteration: 5000
# Total loss: 2.33e+06, style loss: 8.34e+05, content loss: 1.49e+06, time: 0.0727s

# %%
style.show_results()

# %%
style.save_gif('style_mognolia_flower.gif')
