# %%
import style
# Out:
# 2022-05-31 09:44:14.171004: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-31 09:44:14.171042: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
path_content = 'img/c40-recharge-scattered-gallery-1-4x3.jpg'
path_style = 'img/style_green_van.JPG'

# %%
style.show_inputs(path_content, path_style)

# %%
best_img, best_loss, input_vgg_init = style.styleTransfer(path_content, path_style, 
                                                          iterations=1000, display=True, 
                                                          continue_transfer=True)
# Out:
# Iteration: 999
# Total loss: 1.44e+06, style loss: 7.07e+05, content loss: 7.35e+05, time: 0.0928s

# %%
style.show_results(best_img, path_content, path_style, show_large_final=True)
