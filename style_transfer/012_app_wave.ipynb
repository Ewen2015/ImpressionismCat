# %%
import style2
# Out:
# 2022-06-02 01:41:48.853742: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-02 01:41:48.853777: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
path_content = 'img/c40-recharge-scattered-gallery-1-4x3.jpg'
path_style = 'img/style_kanagawa_great_wave.jpeg'

# %%
style = style2.StyleTransfer(path_content, path_style)

# %%
style.show_inputs()

# %%
style.optimize(iterations=4000, learning_rate=4)
# Out:
# Iteration: 628
# Total loss: 5.34e+06, style loss: 3.80e+06, content loss: 1.54e+06, time: 0.0726s

# %%
style.show_results()

# %%
style.save_gif('style_greatwave.gif')
