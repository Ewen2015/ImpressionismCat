# %%
import style2
# Out:
# 2022-06-01 00:09:18.951887: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-01 00:09:18.951929: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
path_content = 'img/c40-recharge-scattered-gallery-1-4x3.jpg'
path_style = 'img/style_oilpainting_stick.jpg'

# %%
style = style2.StyleTransfer(path_content, path_style)

# %%
style.show_inputs()

# %%
style.optimize(iterations=1000, learning_rate=10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [10], in <module>
# ----> 1 style.optimize(iterations=1000, learning_rate=10)
#
# File ~/DataScienceNotes/style_transfer/style2.py:257, in StyleTransfer.optimize(self, iterations, learning_rate, beta_1, epsilon, display, display_interval, cache_interval, clear_cache)
#     254     self.imgs.append(plot_img)
#     256 IPython.display.clear_output(wait=True)
# --> 257 IPython.display.display_png(Image.fromarray(plot_img))
#     258 print('Iteration: {}'.format(i))
#     259 print('Total loss: {:.2e}, '
#     260       'style loss: {:.2e}, '
#     261       'content loss: {:.2e}, '
#     262       'time: {:.4f}s'.format(self.loss, self.score_style, self.score_content,
#     263                              time.time()-start_time))
#
# ...

# %%
style.show_results()
